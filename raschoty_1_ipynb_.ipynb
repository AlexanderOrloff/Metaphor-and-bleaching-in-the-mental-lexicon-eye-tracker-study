# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-67c69c8b-0bcf-44c1-a6a5-610e09bbb4d9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-67c69c8b-0bcf-44c1-a6a5-610e09bbb4d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
import pandas as pd
#import researchpy as rp
import statsmodels.api as sm
import scipy.stats as stats
# Install pymer4
# !pip install -q pymer4
# load pymer4
from pymer4.models import Lmer
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#      |████████████████████████████████| 59 kB 5.7 MB/s

# %%
# Install pymer4
# !pip install -q pymer4
# load pymer4
from pymer4.models import Lmer
#model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|RECORDING_SESSION_LABEL) + (1|IA_LABEL)', data=df)
model = Lmer('IA_FIRST_FIXATION_DURATION ~ type + (1|IA_LABEL) + (1|RECORDING_SESSION_LABEL)', data=df)
display(model.fit())
# ANOVA results from fitted model
display(model.anova())
# Plot estimated model coefficients 
model.plot_summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-a2eb8b8ef409> in <module>()
#       4 from pymer4.models import Lmer
#       5 #model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|RECORDING_SESSION_LABEL) + (1|IA_LABEL)', data=df)
# ----> 6 model = Lmer('IA_FIRST_FIXATION_DURATION ~ type + (1|IA_LABEL) + (1|RECORDING_SESSION_LABEL)', data=df)
#       7 display(model.fit())
#       8 # ANOVA results from fitted model
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## ПРЕДВАРИТЕЛЬНОЕ

# %%
# !apt-get install r-base
# !pip install -q rpy2
packnames = ('lme4', 'lmerTest', 'emmeans', "geepack")
from rpy2.robjects.packages import importr
from rpy2.robjects.vectors import StrVector
utils = importr("utils")
utils.chooseCRANmirror(ind=1)
utils.install_packages(StrVector(packnames))

# %% [markdown]
# ## FIXATION TIME

# %% [markdown]
# ### VERB

# %%
df = pd.read_csv("fix_v_b.csv", sep = ';')
df.info()


#model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|RECORDING_SESSION_LABEL) + (1|IA_LABEL)', data=df)
model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|IA_LABEL) + (1|RECORDING_SESSION_LABEL)', data=df)
display(model.fit())
# ANOVA results from fitted model
display(model.anova())
# Plot estimated model coefficients 
model.plot_summary()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 352 entries, 0 to 351
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   RECORDING_SESSION_LABEL     352 non-null    object
#  1   IA_FIRST_FIXATION_DURATION  352 non-null    int64
#  2   IA_LABEL                    352 non-null    object
#  3   type                        352 non-null    int64
#  4   Word                        352 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 13.9+ KB
# Formula: log(IA_FIRST_FIXATION_DURATION)~type+(1|IA_LABEL)+(1|RECORDING_SESSION_LABEL)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 352	 Groups: {'RECORDING_SESSION_LABEL': 61.0, 'IA_LABEL': 7.0}
#
# Log-likelihood: -114.067 	 AIC: 228.133
#
# Random effects:
#
#                                 Name    Var    Std
# RECORDING_SESSION_LABEL  (Intercept)  0.029  0.171
# ...

# %%
df = pd.read_csv("fix_v_m.csv", sep = ';')
df.info()


#model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|RECORDING_SESSION_LABEL) + (1|IA_LABEL)', data=df)
model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|IA_LABEL) + (1|RECORDING_SESSION_LABEL)', data=df)
display(model.fit())
# ANOVA results from fitted model
display(model.anova())
# Plot estimated model coefficients 
model.plot_summary()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   RECORDING_SESSION_LABEL     374 non-null    object
#  1   IA_FIRST_FIXATION_DURATION  374 non-null    int64
#  2   IA_LABEL                    374 non-null    object
#  3   type                        374 non-null    int64
#  4   Word                        374 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 14.7+ KB
# Formula: log(IA_FIRST_FIXATION_DURATION)~type+(1|IA_LABEL)+(1|RECORDING_SESSION_LABEL)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 374	 Groups: {'RECORDING_SESSION_LABEL': 61.0, 'IA_LABEL': 7.0}
#
# Log-likelihood: -92.843 	 AIC: 185.686
#
# Random effects:
#
#                                 Name    Var    Std
# RECORDING_SESSION_LABEL  (Intercept)  0.021  0.144
# ...

# %% [markdown]
# ### NOUN

# %%
df = pd.read_csv("A_fix_n_b.csv", sep = ';')
df.info()


#model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|RECORDING_SESSION_LABEL) + (1|IA_LABEL)', data=df)
model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type  + (1|verb) + (1|RECORDING_SESSION_LABEL) + (1|IA_LABEL)', data=df)
display(model.fit())
# ANOVA results from fitted model
display(model.anova())
# Plot estimated model coefficients 
model.plot_summary()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337 entries, 0 to 336
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   RECORDING_SESSION_LABEL     337 non-null    object
#  1   IA_FIRST_FIXATION_DURATION  337 non-null    int64
#  2   IA_LABEL                    337 non-null    object
#  3   type                        337 non-null    int64
#  4   Word                        337 non-null    object
#  5   verb                        337 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 15.9+ KB
# boundary (singular) fit: see help('isSingular')
#
# Formula: log(IA_FIRST_FIXATION_DURATION)~type+(1|verb)+(1|RECORDING_SESSION_LABEL)+(1|IA_LABEL)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 337	 Groups: {'RECORDING_SESSION_LABEL': 61.0, 'IA_LABEL': 14.0, 'verb': 7.0}
#
# Log-likelihood: -121.339 	 AIC: 242.679
#
# Random effects:
#
# ...

# %%
df = pd.read_csv("A_fix_n_m.csv", sep = ';')
df.info()


#model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|RECORDING_SESSION_LABEL) + (1|IA_LABEL)', data=df)
model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type  + (1|RECORDING_SESSION_LABEL) + (1|verb) + (1|IA_LABEL)', data=df)
display(model.fit())
# ANOVA results from fitted model
display(model.anova())
# Plot estimated model coefficients 
model.plot_summary()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368 entries, 0 to 367
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   RECORDING_SESSION_LABEL     368 non-null    object
#  1   IA_FIRST_FIXATION_DURATION  368 non-null    int64
#  2   IA_LABEL                    368 non-null    object
#  3   type                        368 non-null    int64
#  4   Word                        368 non-null    object
#  5   verb                        368 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 17.4+ KB
# Formula: log(IA_FIRST_FIXATION_DURATION)~type+(1|RECORDING_SESSION_LABEL)+(1|verb)+(1|IA_LABEL)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 368	 Groups: {'RECORDING_SESSION_LABEL': 61.0, 'IA_LABEL': 14.0, 'verb': 7.0}
#
# Log-likelihood: -105.738 	 AIC: 211.476
#
# Random effects:
#
#                                 Name    Var    Std
# ...

# %% [markdown]
# ### COMMON

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3b65a1fd-5380-4a62-94eb-82856be6ab1b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3b65a1fd-5380-4a62-94eb-82856be6ab1b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving A_total_n_m.csv to A_total_n_m.csv
# Saving A_fix_n_b.csv to A_fix_n_b (1).csv

# %%
df = pd.read_csv("A_fix_c_b.csv", sep = ';')
df.info()


#model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|RECORDING_SESSION_LABEL) + (1|IA_LABEL)', data=df)
model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|RECORDING_SESSION_LABEL) + (1|verb)', data=df)
display(model.fit())
# ANOVA results from fitted model
display(model.anova())
# Plot estimated model coefficients 
model.plot_summary()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368 entries, 0 to 367
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   RECORDING_SESSION_LABEL     368 non-null    object
#  1   IA_FIRST_FIXATION_DURATION  368 non-null    int64
#  2   IA_LABEL                    368 non-null    object
#  3   type                        368 non-null    int64
#  4   Word                        368 non-null    object
#  5   verb                        368 non-null    object
#  6   Unnamed: 6                  0 non-null      float64
#  7   Unnamed: 7                  0 non-null      float64
#  8   Unnamed: 8                  1 non-null      object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 26.0+ KB
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d6be046c-5b09-4de8-b0f3-941b76290eab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d6be046c-5b09-4de8-b0f3-941b76290eab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving A_fix_c_m.csv to A_fix_c_m.csv

# %% [markdown]
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
df = pd.read_csv("A_fix_c_m.csv", sep = ';')
df.info()


#model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|RECORDING_SESSION_LABEL) + (1|IA_LABEL)', data=df)
model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|RECORDING_SESSION_LABEL) + (1|verb)', data=df)
display(model.fit())
# ANOVA results from fitted model
display(model.anova())
# Plot estimated model coefficients 
model.plot_summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-87a27d068645> in <module>()
# ----> 1 df = pd.read_csv("A_fix_c_m.csv", sep = ';')
#       2 df.info()
#       3
#       4
#       5 #model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|RECORDING_SESSION_LABEL) + (1|IA_LABEL)', data=df)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## GAZE DURATION

# %% [markdown]
# ### VERB

# %%
df = pd.read_csv("gaze_v_b.csv", sep = ';')
df.info()


#model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|RECORDING_SESSION_LABEL) + (1|IA_LABEL)', data=df)
model = Lmer('log(IA_FIRST_RUN_DWELL_TIME) ~ type + (1|IA_LABEL) + (1|RECORDING_SESSION_LABEL)', data=df)
display(model.fit())
# ANOVA results from fitted model
display(model.anova())
# Plot estimated model coefficients 
model.plot_summary()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 353 entries, 0 to 352
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   RECORDING_SESSION_LABEL  353 non-null    object
#  1   IA_FIRST_RUN_DWELL_TIME  353 non-null    int64
#  2   IA_LABEL                 353 non-null    object
#  3   type                     353 non-null    int64
#  4   Word                     353 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 13.9+ KB
# Formula: log(IA_FIRST_RUN_DWELL_TIME)~type+(1|IA_LABEL)+(1|RECORDING_SESSION_LABEL)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 353	 Groups: {'RECORDING_SESSION_LABEL': 61.0, 'IA_LABEL': 7.0}
#
# Log-likelihood: -152.363 	 AIC: 304.727
#
# Random effects:
#
#                                 Name    Var    Std
# RECORDING_SESSION_LABEL  (Intercept)  0.030  0.173
# IA_LABEL                 (Intercept)  0.008  0.087
# ...

# %%
df = pd.read_csv("gaze_v_m.csv", sep = ';')
df.info()


#model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|RECORDING_SESSION_LABEL) + (1|IA_LABEL)', data=df)
model = Lmer('log(IA_FIRST_RUN_DWELL_TIME) ~ type + (1|IA_LABEL) + (1|RECORDING_SESSION_LABEL)', data=df)
display(model.fit())
# ANOVA results from fitted model
display(model.anova())
# Plot estimated model coefficients 
model.plot_summary()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376 entries, 0 to 375
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   RECORDING_SESSION_LABEL  376 non-null    object
#  1   IA_FIRST_RUN_DWELL_TIME  376 non-null    int64
#  2   IA_LABEL                 376 non-null    object
#  3   type                     376 non-null    int64
#  4   Word                     376 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 14.8+ KB
# Formula: log(IA_FIRST_RUN_DWELL_TIME)~type+(1|IA_LABEL)+(1|RECORDING_SESSION_LABEL)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 376	 Groups: {'RECORDING_SESSION_LABEL': 61.0, 'IA_LABEL': 7.0}
#
# Log-likelihood: -161.099 	 AIC: 322.198
#
# Random effects:
#
#                                 Name    Var    Std
# RECORDING_SESSION_LABEL  (Intercept)  0.031  0.176
# IA_LABEL                 (Intercept)  0.011  0.106
# ...

# %% [markdown]
# ### NOUN

# %%
df = pd.read_csv("A_gaze_n_b.csv", sep = ';')
df.info()


#model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|RECORDING_SESSION_LABEL) + (1|IA_LABEL)', data=df)
model = Lmer('log(IA_FIRST_RUN_DWELL_TIME) ~ type + (1|IA_LABEL) + (1|RECORDING_SESSION_LABEL)', data=df)
display(model.fit())
# ANOVA results from fitted model
display(model.anova())
# Plot estimated model coefficients 
model.plot_summary()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337 entries, 0 to 336
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   RECORDING_SESSION_LABEL  337 non-null    object
#  1   IA_FIRST_RUN_DWELL_TIME  337 non-null    int64
#  2   IA_LABEL                 337 non-null    object
#  3   type                     337 non-null    int64
#  4   Word                     337 non-null    object
#  5   verb                     337 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 15.9+ KB
# Formula: log(IA_FIRST_RUN_DWELL_TIME)~type+(1|IA_LABEL)+(1|RECORDING_SESSION_LABEL)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 337	 Groups: {'RECORDING_SESSION_LABEL': 61.0, 'IA_LABEL': 14.0}
#
# Log-likelihood: -157.477 	 AIC: 314.955
#
# Random effects:
#
#                                 Name    Var    Std
# RECORDING_SESSION_LABEL  (Intercept)  0.003  0.056
# ...

# %%
df = pd.read_csv("A_gaze_n_m.csv", sep = ';')
df.info()


#model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|RECORDING_SESSION_LABEL) + (1|IA_LABEL)', data=df)
model = Lmer('log(IA_FIRST_RUN_DWELL_TIME) ~ type + (1|RECORDING_SESSION_LABEL)', data=df)
display(model.fit())
# ANOVA results from fitted model
display(model.anova())
# Plot estimated model coefficients 
model.plot_summary()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369 entries, 0 to 368
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   RECORDING_SESSION_LABEL  369 non-null    object
#  1   IA_FIRST_RUN_DWELL_TIME  369 non-null    int64
#  2   IA_LABEL                 369 non-null    object
#  3   type                     369 non-null    int64
#  4   Word                     369 non-null    object
#  5   verb                     369 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 17.4+ KB
# Formula: log(IA_FIRST_RUN_DWELL_TIME)~type+(1|RECORDING_SESSION_LABEL)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 369	 Groups: {'RECORDING_SESSION_LABEL': 61.0}
#
# Log-likelihood: -150.892 	 AIC: 301.785
#
# Random effects:
#
#                                 Name    Var    Std
# RECORDING_SESSION_LABEL  (Intercept)  0.019  0.138
# ...

# %% [markdown]
# ### COMMON

# %%
df = pd.read_csv("A_gaze_c_b.csv", sep = ';')
df.info()


#model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|RECORDING_SESSION_LABEL) + (1|IA_LABEL)', data=df)
model = Lmer('log(IA_FIRST_RUN_DWELL_TIME) ~ type + (1|verb) + (1|RECORDING_SESSION_LABEL)', data=df)
display(model.fit())
# ANOVA results from fitted model
display(model.anova())
# Plot estimated model coefficients 
model.plot_summary()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369 entries, 0 to 368
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   RECORDING_SESSION_LABEL  369 non-null    object
#  1   IA_FIRST_RUN_DWELL_TIME  369 non-null    int64
#  2   IA_LABEL                 369 non-null    object
#  3   type                     369 non-null    int64
#  4   Word                     369 non-null    object
#  5   verb                     369 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 17.4+ KB
# Formula: log(IA_FIRST_RUN_DWELL_TIME)~type+(1|verb)+(1|RECORDING_SESSION_LABEL)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 369	 Groups: {'RECORDING_SESSION_LABEL': 61.0, 'verb': 7.0}
#
# Log-likelihood: -176.974 	 AIC: 353.948
#
# Random effects:
#
#                                 Name    Var    Std
# RECORDING_SESSION_LABEL  (Intercept)  0.027  0.166
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d66cb6ac-73ac-4057-b2ec-022fe55cfb3d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d66cb6ac-73ac-4057-b2ec-022fe55cfb3d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving A_gaze_c_m.csv to A_gaze_c_m.csv

# %%
df = pd.read_csv("A_gaze_c_m.csv", sep = ';')
df.info()


#model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|RECORDING_SESSION_LABEL) + (1|IA_LABEL)', data=df)
model = Lmer('log(IA_FIRST_RUN_DWELL_TIME) ~ type +  (1|RECORDING_SESSION_LABEL) + (1|verb)', data=df)
display(model.fit())
# ANOVA results from fitted model
display(model.anova())
# Plot estimated model coefficients 
model.plot_summary()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   RECORDING_SESSION_LABEL  383 non-null    object
#  1   IA_FIRST_RUN_DWELL_TIME  383 non-null    int64
#  2   IA_LABEL                 383 non-null    object
#  3   type                     383 non-null    int64
#  4   Word                     383 non-null    object
#  5   verb                     383 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 18.1+ KB
# Formula: IA_FIRST_RUN_DWELL_TIME~type+(1|RECORDING_SESSION_LABEL)+(1|verb)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 383	 Groups: {'RECORDING_SESSION_LABEL': 61.0, 'verb': 7.0}
#
# Log-likelihood: -2155.635 	 AIC: 4311.270
#
# Random effects:
#
#                                 Name       Var     Std
# RECORDING_SESSION_LABEL  (Intercept)  1177.764  34.319
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4823dbf1-0ac4-4002-8dea-8368fc33476b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4823dbf1-0ac4-4002-8dea-8368fc33476b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving A_fix_c_b.csv to A_fix_c_b.csv
# Saving A_fix_c_m.csv to A_fix_c_m (1).csv
# Saving A_gaze_c_b.csv to A_gaze_c_b.csv
# Saving A_gaze_c_m.csv to A_gaze_c_m (1).csv
# Saving A_total_c_b.csv to A_total_c_b.csv
# Saving A_total_c_m.csv to A_total_c_m.csv

# %% [markdown]
# ### TOTAL TIME

# %% [markdown]
# ## VERB

# %%
df = pd.read_csv("total_v_b.csv", sep = ';')
df.info()


#model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|RECORDING_SESSION_LABEL) + (1|IA_LABEL)', data=df)
model = Lmer('log(IA_DWELL_TIME) ~ type + (1|IA_LABEL) + (1|RECORDING_SESSION_LABEL)', data=df)
display(model.fit())
# ANOVA results from fitted model
display(model.anova())
# Plot estimated model coefficients 
model.plot_summary()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 353 entries, 0 to 352
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   RECORDING_SESSION_LABEL  353 non-null    object
#  1   IA_DWELL_TIME            353 non-null    int64
#  2   IA_LABEL                 353 non-null    object
#  3   type                     353 non-null    int64
#  4   Word                     353 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 13.9+ KB
# Formula: log(IA_DWELL_TIME)~type+(1|IA_LABEL)+(1|RECORDING_SESSION_LABEL)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 353	 Groups: {'RECORDING_SESSION_LABEL': 61.0, 'IA_LABEL': 7.0}
#
# Log-likelihood: -217.095 	 AIC: 434.191
#
# Random effects:
#
#                                 Name    Var    Std
# RECORDING_SESSION_LABEL  (Intercept)  0.037  0.192
# IA_LABEL                 (Intercept)  0.012  0.111
# ...

# %%
df = pd.read_csv("total_v_m.csv", sep = ';')
df.info()


#model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|RECORDING_SESSION_LABEL) + (1|IA_LABEL)', data=df)
model = Lmer('log(IA_DWELL_TIME) ~ type + (1|IA_LABEL) + (1|RECORDING_SESSION_LABEL)', data=df)
display(model.fit())
# ANOVA results from fitted model
display(model.anova())
# Plot estimated model coefficients 
model.plot_summary()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 377 entries, 0 to 376
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   RECORDING_SESSION_LABEL  377 non-null    object
#  1   IA_DWELL_TIME            377 non-null    int64
#  2   IA_LABEL                 377 non-null    object
#  3   type                     377 non-null    int64
#  4   Word                     377 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 14.9+ KB
# Formula: log(IA_DWELL_TIME)~type+(1|IA_LABEL)+(1|RECORDING_SESSION_LABEL)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 377	 Groups: {'RECORDING_SESSION_LABEL': 61.0, 'IA_LABEL': 7.0}
#
# Log-likelihood: -207.479 	 AIC: 414.959
#
# Random effects:
#
#                                 Name    Var    Std
# RECORDING_SESSION_LABEL  (Intercept)  0.033  0.181
# IA_LABEL                 (Intercept)  0.020  0.142
# ...

# %% [markdown]
# ### NOUN

# %%
df = pd.read_csv("A_total_n_b.csv", sep = ';')
df.info()


#model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|RECORDING_SESSION_LABEL) + (1|IA_LABEL)', data=df)
model = Lmer('log(IA_DWELL_TIME) ~ type + (1|verb) + (1|RECORDING_SESSION_LABEL)', data=df)
display(model.fit())
# ANOVA results from fitted model
display(model.anova())
# Plot estimated model coefficients 
model.plot_summary()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 338 entries, 0 to 337
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   RECORDING_SESSION_LABEL  338 non-null    object
#  1   IA_DWELL_TIME            338 non-null    int64
#  2   IA_LABEL                 338 non-null    object
#  3   type                     338 non-null    int64
#  4   Word                     338 non-null    object
#  5   verb                     338 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 16.0+ KB
# Formula: log(IA_DWELL_TIME)~type+(1|verb)+(1|RECORDING_SESSION_LABEL)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 338	 Groups: {'RECORDING_SESSION_LABEL': 61.0, 'verb': 7.0}
#
# Log-likelihood: -224.904 	 AIC: 449.807
#
# Random effects:
#
#                                 Name    Var    Std
# RECORDING_SESSION_LABEL  (Intercept)  0.009  0.096
# ...

# %%
df = pd.read_csv("A_total_n_m.csv", sep = ';')
df.info()


#model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|RECORDING_SESSION_LABEL) + (1|IA_LABEL)', data=df)
model = Lmer('log(IA_DWELL_TIME) ~ type + (1|RECORDING_SESSION_LABEL) +(1|verb)', data=df)
display(model.fit())
# ANOVA results from fitted model
display(model.anova())
# Plot estimated model coefficients 
model.plot_summary()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369 entries, 0 to 368
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   RECORDING_SESSION_LABEL  369 non-null    object
#  1   IA_DWELL_TIME            369 non-null    int64
#  2   IA_LABEL                 369 non-null    object
#  3   type                     369 non-null    int64
#  4   Word                     369 non-null    object
#  5   verb                     369 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 17.4+ KB
# Formula: log(IA_DWELL_TIME)~type+(1|RECORDING_SESSION_LABEL)+(1|verb)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 369	 Groups: {'RECORDING_SESSION_LABEL': 61.0, 'verb': 7.0}
#
# Log-likelihood: -197.988 	 AIC: 395.975
#
# Random effects:
#
#                                 Name    Var    Std
# RECORDING_SESSION_LABEL  (Intercept)  0.023  0.151
# ...

# %% [markdown]
# ### COMMON

# %%
df = pd.read_csv("A_total_c_b.csv", sep = ';')
df.info()


#model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|RECORDING_SESSION_LABEL) + (1|IA_LABEL)', data=df)
model = Lmer('log(IA_DWELL_TIME) ~ type + (1|verb) + (1|RECORDING_SESSION_LABEL)', data=df)
display(model.fit())
# ANOVA results from fitted model
display(model.anova())
# Plot estimated model coefficients 
model.plot_summary()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 0 to 369
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   RECORDING_SESSION_LABEL  370 non-null    object
#  1   IA_DWELL_TIME            370 non-null    int64
#  2   IA_LABEL                 370 non-null    object
#  3   type                     370 non-null    int64
#  4   Word                     370 non-null    object
#  5   verb                     370 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 17.5+ KB
# Formula: log(IA_DWELL_TIME)~type+(1|verb)+(1|RECORDING_SESSION_LABEL)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 370	 Groups: {'RECORDING_SESSION_LABEL': 61.0, 'verb': 7.0}
#
# Log-likelihood: -254.808 	 AIC: 509.617
#
# Random effects:
#
#                                 Name    Var    Std
# RECORDING_SESSION_LABEL  (Intercept)  0.020  0.141
# ...

# %%
df = pd.read_csv("A_total_c_m.csv", sep = ';')
df.info()


#model = Lmer('log(IA_FIRST_FIXATION_DURATION) ~ type + (1|RECORDING_SESSION_LABEL) + (1|IA_LABEL)', data=df)
model = Lmer('log(IA_DWELL_TIME) ~ type + (1|verb) + (1|RECORDING_SESSION_LABEL)', data=df)
display(model.fit())
# ANOVA results from fitted model
display(model.anova())
# Plot estimated model coefficients 
model.plot_summary()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 383 entries, 0 to 382
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   RECORDING_SESSION_LABEL  383 non-null    object
#  1   IA_DWELL_TIME            383 non-null    int64
#  2   IA_LABEL                 383 non-null    object
#  3   type                     383 non-null    int64
#  4   Word                     383 non-null    object
#  5   verb                     383 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 18.1+ KB
# Formula: log(IA_DWELL_TIME)~type+(1|verb)+(1|RECORDING_SESSION_LABEL)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 383	 Groups: {'RECORDING_SESSION_LABEL': 61.0, 'verb': 7.0}
#
# Log-likelihood: -167.849 	 AIC: 335.699
#
# Random effects:
#
#                                 Name    Var    Std
# RECORDING_SESSION_LABEL  (Intercept)  0.013  0.114
# ...
